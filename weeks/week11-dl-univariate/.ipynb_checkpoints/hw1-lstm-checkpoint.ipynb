# %% [markdown]
# # Homework 1
# In this assignment, you'll prep the standard airline passenger dataset into one suiteable for LSTM using **2 different methods**:
# 1. **`custom_ts_univariate_data_prep`**: the custom function learned in this week's Vishwas chapter
# 2. **`TimeseriesGenerator`**: A standard Keras utility
#
# Then, you'll build a simple LSTM architecture and fit a model to it.  Finally, you'll plot this training & validation loss over the epochs and generate some predictions

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
#
# We'll use the standard airline passengers dataset

# %%
# CODE HERE

# %%
df = pd.read_csv('../../data/airline_passengers.csv',index_col='Month',parse_dates=True)
df.columns = ['Value']
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Problem 1: `Figure out Train/Test Split`
# Compute the length of the dataset & then split it into train/test dataframes where the test set is the last 12 months of data.  Print the shape of the train and test data frames

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# train.shape =  (132, 1)
# test.shape =  (12, 1)

# %% [markdown]
# # Problem 2:  `Scale Data`
# Use a `MinMaxScaler` to appropriate scale the train and test sets into scaled versions.
#
# Print the first 10 values of the `scaled_train` set to verify they're now all between 0 & 1

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# [[0.01758242]
#  [0.03076923]
#  [0.06153846]
#  [0.05494505]
#  [0.03736264]
#  [0.06813187]
#  [0.0967033 ]
#  [0.0967033 ]
#  [0.07032967]
#  [0.03296703]]

# %% [markdown]
# # Problem 3: `Time Series Generator`
#
# Create a TimeSeriesGenerator object based off the scaled_train data using 12 months of lagged inputs.
#
# Print the first prepped time series that comes out of the generator

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# [[[0.01758242]
#   [0.03076923]
#   [0.06153846]
#   [0.05494505]
#   [0.03736264]
#   [0.06813187]
#   [0.0967033 ]
#   [0.0967033 ]
#   [0.07032967]
#   [0.03296703]
#   [0.        ]
#   [0.03076923]]]
# [[0.02417582]]

# %%
def custom_ts_univariate_data_prep(dataset, start, end, window, horizon):
  X = []
  y = []

  start = start + window
  if end is None:
    end = len(dataset) - horizon

  for i in range(start, end):
    indicesx = range(i-window, i)
    X.append(np.reshape(dataset[indicesx], (window, 1)))
    indicesy = range(i,i+horizon)
    y.append(dataset[indicesy])
  return np.array(X), np.array(y)

# %% [markdown]
# # Problem 4 `Custom TS Prep`
# Using the above `custom_ts_univariate_data_prep` function we applied during the lecture, apply it to our `scaled_train` DF show how it's first batch of X and y are equivalent to the ones produced by Keras's `TimeseriesGenerator`

# %%
# CODE HERe

# %%
# Don't delete - try to reproduce the output below
# Out:
# [[0.01758242]
#  [0.03076923]
#  [0.06153846]
#  [0.05494505]
#  [0.03736264]
#  [0.06813187]
#  [0.0967033 ]
#  [0.0967033 ]
#  [0.07032967]
#  [0.03296703]
#  [0.        ]
#  [0.03076923]]
# [[0.02417582]]

# %% [markdown]
# # Problem 5:  `Create the Model`
#
# Create a Keras Sequential Model with as many LSTM units you want and a final Dense Layer.
#
# Display the model summary after compliling it

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 150)               91200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 151
# ...
# Total params: 91,351
# Trainable params: 91,351
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Problem 6: `Fit the Model`
# Train the created model by using the generator.  Use as many epochs as you have patience for

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# /anaconda/envs/py38_tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 120/120 [==============================] - 2s 5ms/step - loss: 0.0620
# Epoch 2/50
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0125
# Epoch 3/50
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0099
# Epoch 4/50
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 5/50
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0097
# Epoch 6/50
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0109
# Epoch 7/50
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0079
# Epoch 8/50
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0061
# ...

# %% [markdown]
# # Problem 6 `Plot history of loss during training`

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below

# %% [markdown]
# # Problem 7  `Evaluate on Test Data`
# Reshape the following `first_eval_batch` into a shape suitable for applying model predictions upon and call it `current_batch`
#
# Print out the shape of the `current_batch`

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# current_batch.shape =  (1, 12, 1)

# %% [markdown]
# # Problem 8: `Generate Predictions`
# Using your reshaping above, generate predictions into the same timestamps as the test set.
#
# Call these predictions `test_predictions` & print them out

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# [array([0.6625498], dtype=float32),
#  array([0.65697217], dtype=float32),
#  array([0.7372023], dtype=float32),
#  array([0.77776504], dtype=float32),
#  array([0.84324276], dtype=float32),
#  array([0.98910934], dtype=float32),
#  array([1.1497836], dtype=float32),
#  array([1.1632046], dtype=float32),
#  array([0.9760011], dtype=float32),
#  array([0.80106074], dtype=float32),
#  array([0.7006142], dtype=float32),
#  array([0.727787], dtype=float32)]

# %% [markdown]
# # Problem 8: `Inverse Transform`
# Using our previously fit `scaler` inversely transform the test predictions back into original scale & add a new column called `Predictions` to our `test` DataFrame.
#
# Print out this head of this `test` DataFrame

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# <ipython-input-52-81ff6aecbb8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions
#             Value  Predictions
# Month
# 1960-01-01    417   405.460156
# 1960-02-01    391   402.922337
# 1960-03-01    419   439.427040
# 1960-04-01    461   457.883091
# 1960-05-01    472   487.675458
# 1960-06-01    535   554.044748
# 1960-07-01    622   627.151543
# 1960-08-01    606   633.258071
# 1960-09-01    508   548.080493
# 1960-10-01    461   468.482635
# 1960-11-01    390   422.779467
# 1960-12-01    432   435.143093

# %% [markdown]
# # Problem 9: `Plot out the test set against the predictions`

# %%
# CODE HERE

# %%
# Don't delete - try to reproduce the output below
# Out:
# <AxesSubplot:xlabel='Month'>
