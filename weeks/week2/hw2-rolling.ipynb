# %% [markdown]
# # Rolling and Expanding
#
# A common process with time series is to create data based off of a rolling mean. The idea is to divide the data into "windows" of time, and then calculate an aggregate function for each window. In this way we obtain a <em>simple moving average</em>. Let's show how to do this easily with pandas!

# %%
import pandas as pd
# %matplotlib inline

# %%
# Import the data:
df = pd.read_csv('../../data/starbucks.csv', index_col='Date', parse_dates=True)

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df['Close'].plot(figsize=(12,5)).autoscale(axis='x',tight=True);

# %% [markdown]
# ## Problem 1: `rolling`
# Compute a rolling 30 day mean of the close price & then plot it along side the close.

# %%
#code here

# %%
#try to reproduce this - don't delete

# %% [markdown]
# ## Problem 2: `expanding`
#
# Instead of calculating values for a rolling window of dates, use `expanding` to take into account everything from the start of the time series up to each point in time.  Plot the result

# %%
#code here

# %%
#try to reproduce this - don't delete
